# %%
from utils import Dataset ,perceptron
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
def plot1(inputs,weights):
    sns.scatterplot(data=inputs,x="X",y="Y",hue='Labels',s=2).set(title='plot with decision boundary')
    inputs=np.array(inputs)
    Ya_nn=[]
    ia_nn=[]
    for i in np.linspace(np.amin(inputs[:,:1]),np.amax(inputs[:,:1])):
            slope = -(weights[1])/(weights[2])  
            intercept = -(weights[0]/weights[2])
            #y =mx+c, m is slope and c is intercept
            y = (slope*i) + intercept
            ia_nn.append(i)
            Ya_nn.append(y)
    sns.lineplot(x=ia_nn,y=Ya_nn,color='black',markersize=4)
    plt.legend()
    plt.show()

# %% [markdown]
# ### Part 1

# %%
#without noise 10,000 samples
d=Dataset(10_000)
df=d.get()
df
# Out:
#              X         Y  Labels
# 0     0.423639 -0.905831       0
# 1    -0.330051 -0.943963       0
# 2    -0.608859  3.793278       1
# 3    -0.204892 -0.978785       0
# 4    -0.630064  2.223457       1
# ...        ...       ...     ...
# 9995 -0.622334  0.782751       0
# 9996 -0.990131  2.859854       1
# 9997 -0.542516  3.840046       1
# 9998 -0.932359  2.638465       1
# 9999 -0.199614  0.979875       0
#
# [10000 rows x 3 columns]

# %%
# d=Dataset(10000) with noise added
df1=d.get(True)
df1
# Out:
#              X         Y  Labels
# 0    -0.295458  3.818057       1
# 1     0.277812  4.016383       1
# 2    -0.488888  3.784039       1
# 3    -0.598426  2.132802       1
# 4    -0.691098  3.615312       1
# ...        ...       ...     ...
# 9995 -0.472773  0.998201       0
# 9996  0.796622  0.534594       0
# 9997  0.998779 -0.150359       0
# 9998 -0.862459 -0.718366       0
# 9999  0.151220  0.953026       0
#
# [10000 rows x 3 columns]

# %%
df.shape
# Out:
# (10000, 3)

# %%
df1.shape
# Out:
# (10000, 3)

# %% [markdown]
# ### Part 2

# %%
sns.scatterplot(data=df,x="X",y="Y",hue='Labels').set(title='Without noise')
plt.show()

# %%
sns.scatterplot(data=df1,x="X",y="Y",hue='Labels').set(title='With Noise')
plt.show()

# %% [markdown]
# ### Part 3

# %%
p=perceptron()
# trainning the perceptron with learnable bias on without noise data
p.train_weights(np.array(df),5,1)
# Out:
# >epoch=0, error=7.000 [-3.0, 0.3218420928247345, 2.2500605663202204]
# >epoch=1, error=0.000 [-3.0, 0.3218420928247345, 2.2500605663202204]
# >epoch=2, error=0.000 [-3.0, 0.3218420928247345, 2.2500605663202204]
# >epoch=3, error=0.000 [-3.0, 0.3218420928247345, 2.2500605663202204]
# >epoch=4, error=0.000 [-3.0, 0.3218420928247345, 2.2500605663202204]

# %%
plot1(df,p.weights)

# %%
p1=perceptron()
# the third parameter is a flag to make bias 0 or learnable
p1.train_weights(np.array(df1),5,1)
# Out:
# >epoch=0, error=7.000 [-3.0, -0.2228441895346185, 2.060545380610784]
# >epoch=1, error=0.000 [-3.0, -0.2228441895346185, 2.060545380610784]
# >epoch=2, error=0.000 [-3.0, -0.2228441895346185, 2.060545380610784]
# >epoch=3, error=0.000 [-3.0, -0.2228441895346185, 2.060545380610784]
# >epoch=4, error=0.000 [-3.0, -0.2228441895346185, 2.060545380610784]

# %%
plot1(df1,p1.weights)

# %%
plot_decision_boundary()
